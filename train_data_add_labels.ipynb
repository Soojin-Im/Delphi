# %% [markdown]
# <a href="https://colab.research.google.com/github/Soojin-Im/Delphi/blob/main/train_data_add_labels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# 이미 정제 완료된 snythetic data의 형식을 확인하는 코드 (아래는 실제 ukb 데이터가 있을 때 그것을 변환하는 코드)

train_path = "/content/drive/MyDrive/STUDY/Delphi/data/ukb_simulated_data/train.bin"
data = np.fromfile(train_path, dtype=np.uint32).reshape(-1, 3)

df = pd.DataFrame(data, columns=["patient_id", "patient_age_days", "token_id"])

print("원본 데이터:")
print(df.head())
print(f"\n데이터 shape: {df.shape}")
print(f"\npatient_id 분포:")
print(df["patient_id"].value_counts().head())
print(f"\ntoken_id 분포 (상위 10개):")
print(df["token_id"].value_counts().head(10))
# Out:
# 원본 데이터:
#    patient_id  patient_age_days  token_id
# 0      402867              1251       602
# 1      402867              8870       724
# 2      402867             15534       714
# 3      402867             21457       498
# 4      402867             21834       265
#
# 데이터 shape: (181293, 3)
#
# patient_id 분포:
# patient_id
# 416380    64
# 422428    64
# 403098    63
# 414908    63
# 417552    62
# Name: count, dtype: int64
#
# token_id 분포 (상위 10개):
# token_id
# 498    4181
# 833    3677
# 1      3639
# 2      3503
# 797    3302
# 265    3083
# 791    2918
# 586    2883
# 817    2687
# 438    2407
# Name: count, dtype: int64

# %%
data
# Out:
# array([[402867,   1251,    602],
#        [402867,   8870,    724],
#        [402867,  15534,    714],
#        ...,
#        [427985,  21171,    312],
#        [427985,  21579,    265],
#        [427985,  24842,    217]], dtype=uint32)

# %%
# labels.csv 파일 읽기
labels_path = "/content/drive/MyDrive/STUDY/Delphi/data/ukb_simulated_data/labels.csv"
with open(labels_path, 'r', encoding='utf-8') as f:
    labels = [line.strip() for line in f.readlines()]

# labels.csv의 1번째 행(Padding)과 2번째 행(No event)는 모두 token_id 0에 해당
# labels.csv의 3번째 행(Female)부터 token_id 1로 시작
# 즉: token_id 0 -> Padding 또는 No event, token_id 1 -> Female, token_id 2 -> Male, ...
label_dict = {}
# token_id 0은 Padding (또는 No event도 가능하지만 Padding을 기본으로)
label_dict[0] = labels[0]  # Padding
# token_id 1부터는 labels.csv의 인덱스 2부터 매핑
for token_id in range(1, len(labels) - 1):  # token_id 1부터 시작
    label_dict[token_id] = labels[token_id + 1]  # labels[2] -> token_id 1, labels[3] -> token_id 2, ...
label_dict
# Out:
# {0: 'Padding',
#  1: 'Female',
#  2: 'Male',
#  3: 'BMI_low',
#  4: 'BMI_mid',
#  5: 'BMI_high',
#  6: 'Smoking_low',
#  7: 'Smoking_mid',
#  8: 'Smoking_high',
#  9: 'Alcohol_low',
#  10: 'Alcohol_mid',
#  11: 'Alcohol_high',
#  12: 'A00 (cholera)',
#  13: 'A01 (typhoid and paratyphoid fevers)',
#  14: 'A02 (other salmonella infections)',
#  15: 'A03 (shigellosis)',
#  16: 'A04 (other bacterial intestinal infections)',
#  17: 'A05 (other bacterial foodborne intoxications)',
#  18: 'A06 (amoebiasis)',
#  19: 'A07 (other protozoal intestinal diseases)',
#  20: 'A08 (viral and other specified intestinal infections)',
#  21: 'A09 (diarrhoea and gastro-enteritis of presumed infectious origin)',
#  22: 'A15 (respiratory tuberculosis, bacteriologically and histologically confirmed)',
#  23: 'A16 (respiratory tuberculosis, not confirmed bacteriologically or histologically)',
#  24: 'A17 (tuberculosis of nervous system)',
#  25: 'A18 (tuberculosis of other organs)',
#  26: 'A19 (miliary tuberculosis)',
#  27: 'A20 (plague)',
#  28: 'A22 (anthrax)',
#  29: 'A23 (brucellosis)',
#  30: 'A24 (glanders and melioidosis)',
#  31: 'A25 (rat-bite fevers)',
#  32: 'A26 (erysipeloid)',
#  33: 'A27 (leptospirosis)',
#  34: 'A28 (other zoonotic bacterial diseases, not elsewhere classified)',
#  35: "A30 (leprosy [hansen's disease])",
#  36: 'A31 (infection due to other mycobacteria)',
#  37: 'A32 (listeriosis)',
#  38: 'A33 (tetanus neonatorum)',
#  39: 'A35 (other tetanus)',
#  40: 'A36 (diphtheria)',
#  41: 'A37 (whooping cough)',
#  42: 'A38 (scarlet fever)',
#  43: 'A39 (meningococcal infection)',
#  44: 'A40 (streptococcal septicaemia)',
#  45: 'A41 (other septicaemia)',
#  46: 'A42 (actinomycosis)',
#  47: 'A43 (nocardiosis)',
#  48: 'A44 (bartonellosis)',
#  49: 'A46 (erysipelas)',
#  50: 'A48 (other bacterial diseases, not elsewhere classified)',
#  51: 'A49 (bacterial infection of unspecified site)',
#  52: 'A50 (congenital syphilis)',
#  53: 'A51 (early syphilis)',
#  54: 'A52 (late syphilis)',
#  55: 'A53 (other and unspecified syphilis)',
#  56: 'A54 (gonococcal infection)',
#  57: 'A55 (chlamydial lymphogranuloma (venereum))',
#  58: 'A56 (other sexually transmitted chlamydial diseases)',
#  59: 'A58 (granuloma inguinale)',
#  60: 'A59 (trichomoniasis)',
#  61: 'A60 (anogenital herpesviral [herpes simplex] infections)',
#  62: 'A63 (other predominantly sexually transmitted diseases, not elsewhere classified)',
#  63: 'A64 (unspecified sexually transmitted disease)',
#  64: 'A66 (yaws)',
#  65: 'A67 (pinta [carate])',
#  66: 'A68 (relapsing fevers)',
#  67: 'A69 (other spirochaetal infections)',
#  68: 'A70 (chlamydia psittaci infection)',
#  69: 'A71 (trachoma)',
#  70: 'A74 (other diseases caused by chlamydiae)',
#  71: 'A75 (typhus fever)',
#  72: 'A77 (spotted fever [tick-borne rickettsioses])',
#  73: 'A78 (q fever)',
#  74: 'A79 (other rickettsioses)',
#  75: 'A80 (acute poliomyelitis)',
#  76: 'A81 (atypical virus infections of central nervous system)',
#  77: 'A82 (rabies)',
#  78: 'A83 (mosquito-borne viral encephalitis)',
#  79: 'A84 (tick-borne viral encephalitis)',
#  80: 'A85 (other viral encephalitis, not elsewhere classified)',
#  81: 'A86 (unspecified viral encephalitis)',
#  82: 'A87 (viral meningitis)',
#  83: 'A88 (other viral infections of central nervous system, not elsewhere classified)',
#  84: 'A89 (unspecified viral infection of central nervous system)',
#  85: 'A90 (dengue fever [classical dengue])',
#  86: 'A91 (dengue haemorrhagic fever)',
#  87: 'A92 (other mosquito-borne viral fevers)',
#  88: 'A93 (other arthropod-borne viral fevers, not elsewhere classified)',
#  89: 'A94 (unspecified arthropod-borne viral fever)',
#  90: 'A95 (yellow fever)',
#  91: 'A97 (dengue)',
#  92: 'A98 (other viral haemorrhagic fevers, not elsewhere classified)',
#  93: 'B00 (herpesviral [herpes simplex] infections)',
#  94: 'B01 (varicella [chickenpox])',
#  95: 'B02 (zoster [herpes zoster])',
#  96: 'B03 (smallpox)',
#  97: 'B05 (measles)',
#  98: 'B06 (rubella [german measles])',
#  99: 'B07 (viral warts)',
#  100: 'B08 (other viral infections characterised by skin and mucous membrane lesions, not elsewhere classified)',
#  101: 'B09 (unspecified viral infection characterised by skin and mucous membrane lesions)',
#  102: 'B15 (acute hepatitis a)',
#  103: 'B16 (acute hepatitis b)',
#  104: 'B17 (other acute viral hepatitis)',
#  105: 'B18 (chronic viral hepatitis)',
#  106: 'B19 (unspecified viral hepatitis)',
#  107: 'B20 (human immunodeficiency virus [hiv] disease resulting in infectious and parasitic diseases)',
#  108: 'B21 (human immunodeficiency virus [hiv] disease resulting in malignant neoplasms)',
#  109: 'B22 (human immunodeficiency virus [hiv] disease resulting in other specified diseases)',
#  110: 'B23 (human immunodeficiency virus [hiv] disease resulting in other conditions)',
#  111: 'B24 (unspecified human immunodeficiency virus [hiv] disease)',
#  112: 'B25 (cytomegaloviral disease)',
#  113: 'B26 (mumps)',
#  114: 'B27 (infectious mononucleosis)',
#  115: 'B30 (viral conjunctivitis)',
#  116: 'B33 (other viral diseases, not elsewhere classified)',
#  117: 'B34 (viral infection of unspecified site)',
#  118: 'B35 (dermatophytosis)',
#  119: 'B36 (other superficial mycoses)',
#  120: 'B37 (candidiasis)',
#  121: 'B38 (coccidioidomycosis)',
#  122: 'B39 (histoplasmosis)',
#  123: 'B40 (blastomycosis)',
#  124: 'B42 (sporotrichosis)',
#  125: 'B43 (chromomycosis and phaeomycotic abscess)',
#  126: 'B44 (aspergillosis)',
#  127: 'B45 (cryptococcosis)',
#  128: 'B46 (zygomycosis)',
#  129: 'B47 (mycetoma)',
#  130: 'B48 (other mycoses, not elsewhere classified)',
#  131: 'B49 (unspecified mycosis)',
#  132: 'B50 (plasmodium falciparum malaria)',
#  133: 'B51 (plasmodium vivax malaria)',
#  134: 'B52 (plasmodium malariae malaria)',
#  135: 'B53 (other parasitologically confirmed malaria)',
#  136: 'B54 (unspecified malaria)',
#  137: 'B55 (leishmaniasis)',
#  138: "B57 (chagas' disease)",
#  139: 'B58 (toxoplasmosis)',
#  140: 'B59 (pneumocystosis)',
#  141: 'B60 (other protozoal diseases, not elsewhere classified)',
#  142: 'B65 (schistosomiasis [bilharziasis])',
#  143: 'B66 (other fluke infections)',
#  144: 'B67 (echinococcosis)',
#  145: 'B68 (taeniasis)',
#  146: 'B69 (cysticercosis)',
#  147: 'B71 (other cestode infections)',
#  148: 'B73 (onchocerciasis)',
#  149: 'B74 (filariasis)',
#  150: 'B75 (trichinellosis)',
#  151: 'B76 (hookworm diseases)',
#  152: 'B77 (ascariasis)',
#  153: 'B78 (strongyloidiasis)',
#  154: 'B79 (trichuriasis)',
#  155: 'B80 (enterobiasis)',
#  156: 'B81 (other intestinal helminthiases, not elsewhere classified)',
#  157: 'B82 (unspecified intestinal parasitism)',
#  158: 'B83 (other helminthiases)',
#  159: 'B85 (pediculosis and phthiriasis)',
#  160: 'B86 (scabies)',
#  161: 'B87 (myiasis)',
#  162: 'B88 (other infestations)',
#  163: 'B89 (unspecified parasitic disease)',
#  164: 'B90 (sequelae of tuberculosis)',
#  165: 'B91 (sequelae of poliomyelitis)',
#  166: 'B94 (sequelae of other and unspecified infectious and parasitic diseases)',
#  167: 'B95 (streptococcus and staphylococcus as the cause of diseases classified to other chapters)',
#  168: 'B96 (other bacterial agents as the cause of diseases classified to other chapters)',
#  169: 'B97 (viral agents as the cause of diseases classified to other chapters)',
#  170: 'B98 (other specified infectious agents as the cause of diseases classified to other chapters)',
#  171: 'B99 (other and unspecified infectious diseases)',
#  172: 'D50 (iron deficiency anaemia)',
#  173: 'D51 (vitamin b12 deficiency anaemia)',
#  174: 'D52 (folate deficiency anaemia)',
#  175: 'D53 (other nutritional anaemias)',
#  176: 'D55 (anaemia due to enzyme disorders)',
#  177: 'D56 (thalassaemia)',
#  178: 'D57 (sickle-cell disorders)',
#  179: 'D58 (other hereditary haemolytic anaemias)',
#  180: 'D59 (acquired haemolytic anaemia)',
#  181: 'D60 (acquired pure red cell aplasia [erythroblastopenia])',
#  182: 'D61 (other aplastic anaemias)',
#  183: 'D62 (acute posthaemorrhagic anaemia)',
#  184: 'D63 (anaemia in chronic diseases classified elsewhere)',
#  185: 'D64 (other anaemias)',
#  186: 'D65 (disseminated intravascular coagulation [defibrination syndrome])',
#  187: 'D66 (hereditary factor viii deficiency)',
#  188: 'D67 (hereditary factor ix deficiency)',
#  189: 'D68 (other coagulation defects)',
#  190: 'D69 (purpura and other haemorrhagic conditions)',
#  191: 'D70 (agranulocytosis)',
#  192: 'D71 (functional disorders of polymorphonuclear neutrophils)',
#  193: 'D72 (other disorders of white blood cells)',
#  194: 'D73 (diseases of spleen)',
#  195: 'D74 (methaemoglobinaemia)',
#  196: 'D75 (other diseases of blood and blood-forming organs)',
#  197: 'D76 (certain diseases involving lymphoreticular tissue and reticulohistiocytic system)',
#  198: 'D77 (other disorders of blood and blood-forming organs in diseases classified elsewhere)',
#  199: 'D80 (immunodeficiency with predominantly antibody defects)',
#  200: 'D81 (combined immunodeficiencies)',
#  201: 'D82 (immunodeficiency associated with other major defects)',
#  202: 'D83 (common variable immunodeficiency)',
#  203: 'D84 (other immunodeficiencies)',
#  204: 'D86 (sarcoidosis)',
#  205: 'D89 (other disorders involving the immune mechanism, not elsewhere classified)',
#  206: 'E01 (iodine-deficiency-related thyroid disorders and allied conditions)',
#  207: 'E02 (subclinical iodine-deficiency hypothyroidism)',
#  208: 'E03 (other hypothyroidism)',
#  209: 'E04 (other non-toxic goitre)',
#  210: 'E05 (thyrotoxicosis [hyperthyroidism])',
#  211: 'E06 (thyroiditis)',
#  212: 'E07 (other disorders of thyroid)',
#  213: 'E10 (insulin-dependent diabetes mellitus)',
#  214: 'E11 (non-insulin-dependent diabetes mellitus)',
#  215: 'E12 (malnutrition-related diabetes mellitus)',
#  216: 'E13 (other specified diabetes mellitus)',
#  217: 'E14 (unspecified diabetes mellitus)',
#  218: 'E15 (nondiabetic hypoglycaemic coma)',
#  219: 'E16 (other disorders of pancreatic internal secretion)',
#  220: 'E20 (hypoparathyroidism)',
#  221: 'E21 (hyperparathyroidism and other disorders of parathyroid gland)',
#  222: 'E22 (hyperfunction of pituitary gland)',
#  223: 'E23 (hypofunction and other disorders of pituitary gland)',
#  224: "E24 (cushing's syndrome)",
#  225: 'E25 (adrenogenital disorders)',
#  226: 'E26 (hyperaldosteronism)',
#  227: 'E27 (other disorders of adrenal gland)',
#  228: 'E28 (ovarian dysfunction)',
#  229: 'E29 (testicular dysfunction)',
#  230: 'E30 (disorders of puberty, not elsewhere classified)',
#  231: 'E31 (polyglandular dysfunction)',
#  232: 'E32 (diseases of thymus)',
#  233: 'E34 (other endocrine disorders)',
#  234: 'E35 (disorders of endocrine glands in diseases classified elsewhere)',
#  235: 'E41 (nutritional marasmus)',
#  236: 'E43 (unspecified severe protein-energy malnutrition)',
#  237: 'E44 (protein-energy malnutrition of moderate and mild degree)',
#  238: 'E45 (retarded development following protein-energy malnutrition)',
#  239: 'E46 (unspecified protein-energy malnutrition)',
#  240: 'E50 (vitamin a deficiency)',
#  241: 'E51 (thiamine deficiency)',
#  242: 'E52 (niacin deficiency [pellagra])',
#  243: 'E53 (deficiency of other b group vitamins)',
#  244: 'E54 (ascorbic acid deficiency)',
#  245: 'E55 (vitamin d deficiency)',
#  246: 'E56 (other vitamin deficiencies)',
#  247: 'E58 (dietary calcium deficiency)',
#  248: 'E59 (dietary selenium deficiency)',
#  249: 'E60 (dietary zinc deficiency)',
#  250: 'E61 (deficiency of other nutrient elements)',
#  251: 'E63 (other nutritional deficiencies)',
#  252: 'E64 (sequelae of malnutrition and other nutritional deficiencies)',
#  253: 'E65 (localised adiposity)',
#  254: 'E66 (obesity)',
#  255: 'E67 (other hyperalimentation)',
#  256: 'E68 (sequelae of hyperalimentation)',
#  257: 'E70 (disorders of aromatic amino-acid metabolism)',
#  258: 'E71 (disorders of branched-chain amino-acid metabolism and fatty-acid metabolism)',
#  259: 'E72 (other disorders of amino-acid metabolism)',
#  260: 'E73 (lactose intolerance)',
#  261: 'E74 (other disorders of carbohydrate metabolism)',
#  262: 'E75 (disorders of sphingolipid metabolism and other lipid storage disorders)',
#  263: 'E76 (disorders of glycosaminoglycan metabolism)',
#  264: 'E77 (disorders of glycoprotein metabolism)',
#  265: 'E78 (disorders of lipoprotein metabolism and other lipidaemias)',
#  266: 'E79 (disorders of purine and pyrimidine metabolism)',
#  267: 'E80 (disorders of porphyrin and bilirubin metabolism)',
#  268: 'E83 (disorders of mineral metabolism)',
#  269: 'E84 (cystic fibrosis)',
#  270: 'E85 (amyloidosis)',
#  271: 'E86 (volume depletion)',
#  272: 'E87 (other disorders of fluid, electrolyte and acid-base balance)',
#  273: 'E88 (other metabolic disorders)',
#  274: 'E89 (postprocedural endocrine and metabolic disorders, not elsewhere classified)',
#  275: "F00 (dementia in alzheimer's disease)",
#  276: 'F01 (vascular dementia)',
#  277: 'F02 (dementia in other diseases classified elsewhere)',
#  278: 'F03 (unspecified dementia)',
#  279: 'F04 (organic amnesic syndrome, not induced by alcohol and other psychoactive substances)',
#  280: 'F05 (delirium, not induced by alcohol and other psychoactive substances)',
#  281: 'F06 (other mental disorders due to brain damage and dysfunction and to physical disease)',
#  282: 'F07 (personality and behavioural disorders due to brain disease, damage and dysfunction)',
#  283: 'F09 (unspecified organic or symptomatic mental disorder)',
#  284: 'F10 (mental and behavioural disorders due to use of alcohol)',
#  285: 'F11 (mental and behavioural disorders due to use of opioids)',
#  286: 'F12 (mental and behavioural disorders due to use of cannabinoids)',
#  287: 'F13 (mental and behavioural disorders due to use of sedatives or hypnotics)',
#  288: 'F14 (mental and behavioural disorders due to use of cocaine)',
#  289: 'F15 (mental and behavioural disorders due to use of other stimulants, including caffeine)',
#  290: 'F16 (mental and behavioural disorders due to use of hallucinogens)',
#  291: 'F17 (mental and behavioural disorders due to use of tobacco)',
#  292: 'F18 (mental and behavioural disorders due to use of volatile solvents)',
#  293: 'F19 (mental and behavioural disorders due to multiple drug use and use of other psychoactive substances)',
#  294: 'F20 (schizophrenia)',
#  295: 'F21 (schizotypal disorder)',
#  296: 'F22 (persistent delusional disorders)',
#  297: 'F23 (acute and transient psychotic disorders)',
#  298: 'F24 (induced delusional disorder)',
#  299: 'F25 (schizoaffective disorders)',
#  300: 'F28 (other nonorganic psychotic disorders)',
#  301: 'F29 (unspecified nonorganic psychosis)',
#  302: 'F30 (manic episode)',
#  303: 'F31 (bipolar affective disorder)',
#  304: 'F32 (depressive episode)',
#  305: 'F33 (recurrent depressive disorder)',
#  306: 'F34 (persistent mood [affective] disorders)',
#  307: 'F38 (other mood [affective] disorders)',
#  308: 'F39 (unspecified mood [affective] disorder)',
#  309: 'F40 (phobic anxiety disorders)',
#  310: 'F41 (other anxiety disorders)',
#  311: 'F42 (obsessive-compulsive disorder)',
#  312: 'F43 (reaction to severe stress, and adjustment disorders)',
#  313: 'F44 (dissociative [conversion] disorders)',
#  314: 'F45 (somatoform disorders)',
#  315: 'F48 (other neurotic disorders)',
#  316: 'F50 (eating disorders)',
#  317: 'F51 (nonorganic sleep disorders)',
#  318: 'F52 (sexual dysfunction, not caused by organic disorder or disease)',
#  319: 'F53 (mental and behavioural disorders associated with the puerperium, not elsewhere classified)',
#  320: 'F54 (psychological and behavioural factors associated with disorders or diseases classified elsewhere)',
#  321: 'F55 (abuse of non-dependence-producing substances)',
#  322: 'F59 (unspecified behavioural syndromes associated with physiological disturbances and physical factors)',
#  323: 'F60 (specific personality disorders)',
#  324: 'F61 (mixed and other personality disorders)',
#  325: 'F62 (enduring personality changes, not attributable to brain damage and disease)',
#  326: 'F63 (habit and impulse disorders)',
#  327: 'F64 (gender identity disorders)',
#  328: 'F65 (disorders of sexual preference)',
#  329: 'F66 (psychological and behavioural disorders associated with sexual development and orientation)',
#  330: 'F68 (other disorders of adult personality and behaviour)',
#  331: 'F69 (unspecified disorder of adult personality and behaviour)',
#  332: 'F70 (mild mental retardation)',
#  333: 'F71 (moderate mental retardation)',
#  334: 'F72 (severe mental retardation)',
#  335: 'F78 (other mental retardation)',
#  336: 'F79 (unspecified mental retardation)',
#  337: 'F80 (specific developmental disorders of speech and language)',
#  338: 'F81 (specific developmental disorders of scholastic skills)',
#  339: 'F82 (specific developmental disorder of motor function)',
#  340: 'F83 (mixed specific developmental disorders)',
#  341: 'F84 (pervasive developmental disorders)',
#  342: 'F88 (other disorders of psychological development)',
#  343: 'F89 (unspecified disorder of psychological development)',
#  344: 'F90 (hyperkinetic disorders)',
#  345: 'F91 (conduct disorders)',
#  346: 'F92 (mixed disorders of conduct and emotions)',
#  347: 'F93 (emotional disorders with onset specific to childhood)',
#  348: 'F94 (disorders of social functioning with onset specific to childhood and adolescence)',
#  349: 'F95 (tic disorders)',
#  350: 'F98 (other behavioural and emotional disorders with onset usually occurring in childhood and adolescence)',
#  351: 'F99 (mental disorder, not otherwise specified)',
#  352: 'G00 (bacterial meningitis, not elsewhere classified)',
#  353: 'G01 (meningitis in bacterial diseases classified elsewhere)',
#  354: 'G02 (meningitis in other infectious and parasitic diseases classified elsewhere)',
#  355: 'G03 (meningitis due to other and unspecified causes)',
#  356: 'G04 (encephalitis, myelitis and encephalomyelitis)',
#  357: 'G05 (encephalitis, myelitis and encephalomyelitis in diseases classified elsewhere)',
#  358: 'G06 (intracranial and intraspinal abscess and granuloma)',
#  359: 'G07 (intracranial and intraspinal abscess and granuloma in diseases classified elsewhere)',
#  360: 'G08 (intracranial and intraspinal phlebitis and thrombophlebitis)',
#  361: 'G09 (sequelae of inflammatory diseases of central nervous system)',
#  362: "G10 (huntington's disease)",
#  363: 'G11 (hereditary ataxia)',
#  364: 'G12 (spinal muscular atrophy and related syndromes)',
#  365: 'G13 (systemic atrophies primarily affecting central nervous system in diseases classified elsewhere)',
#  366: 'G14 (postpolio syndrome)',
#  367: "G20 (parkinson's disease)",
#  368: 'G21 (secondary parkinsonism)',
#  369: 'G22 (parkinsonism in diseases classified elsewhere)',
#  370: 'G23 (other degenerative diseases of basal ganglia)',
#  371: 'G24 (dystonia)',
#  372: 'G25 (other extrapyramidal and movement disorders)',
#  373: "G30 (alzheimer's disease)",
#  374: 'G31 (other degenerative diseases of nervous system, not elsewhere classified)',
#  375: 'G32 (other degenerative disorders of nervous system in diseases classified elsewhere)',
#  376: 'G35 (multiple sclerosis)',
#  377: 'G36 (other acute disseminated demyelination)',
#  378: 'G37 (other demyelinating diseases of central nervous system)',
#  379: 'G40 (epilepsy)',
#  380: 'G41 (status epilepticus)',
#  381: 'G43 (migraine)',
#  382: 'G44 (other headache syndromes)',
#  383: 'G45 (transient cerebral ischaemic attacks and related syndromes)',
#  384: 'G46 (vascular syndromes of brain in cerebrovascular diseases)',
#  385: 'G47 (sleep disorders)',
#  386: 'G50 (disorders of trigeminal nerve)',
#  387: 'G51 (facial nerve disorders)',
#  388: 'G52 (disorders of other cranial nerves)',
#  389: 'G53 (cranial nerve disorders in diseases classified elsewhere)',
#  390: 'G54 (nerve root and plexus disorders)',
#  391: 'G55 (nerve root and plexus compressions in diseases classified elsewhere)',
#  392: 'G56 (mononeuropathies of upper limb)',
#  393: 'G57 (mononeuropathies of lower limb)',
#  394: 'G58 (other mononeuropathies)',
#  395: 'G59 (mononeuropathy in diseases classified elsewhere)',
#  396: 'G60 (hereditary and idiopathic neuropathy)',
#  397: 'G61 (inflammatory polyneuropathy)',
#  398: 'G62 (other polyneuropathies)',
#  399: 'G63 (polyneuropathy in diseases classified elsewhere)',
#  400: 'G64 (other disorders of peripheral nervous system)',
#  401: 'G70 (myasthenia gravis and other myoneural disorders)',
#  402: 'G71 (primary disorders of muscles)',
#  403: 'G72 (other myopathies)',
#  404: 'G73 (disorders of myoneural junction and muscle in diseases classified elsewhere)',
#  405: 'G80 (infantile cerebral palsy)',
#  406: 'G81 (hemiplegia)',
#  407: 'G82 (paraplegia and tetraplegia)',
#  408: 'G83 (other paralytic syndromes)',
#  409: 'G90 (disorders of autonomic nervous system)',
#  410: 'G91 (hydrocephalus)',
#  411: 'G92 (toxic encephalopathy)',
#  412: 'G93 (other disorders of brain)',
#  413: 'G94 (other disorders of brain in diseases classified elsewhere)',
#  414: 'G95 (other diseases of spinal cord)',
#  415: 'G96 (other disorders of central nervous system)',
#  416: 'G97 (postprocedural disorders of nervous system, not elsewhere classified)',
#  417: 'G98 (other disorders of nervous system, not elsewhere classified)',
#  418: 'G99 (other disorders of nervous system in diseases classified elsewhere)',
#  419: 'H00 (hordeolum and chalazion)',
#  420: 'H01 (other inflammation of eyelid)',
#  421: 'H02 (other disorders of eyelid)',
#  422: 'H03 (disorders of eyelid in diseases classified elsewhere)',
#  423: 'H04 (disorders of lachrymal system)',
#  424: 'H05 (disorders of orbit)',
#  425: 'H06 (disorders of lachrymal system and orbit in diseases classified elsewhere)',
#  426: 'H10 (conjunctivitis)',
#  427: 'H11 (other disorders of conjunctiva)',
#  428: 'H13 (disorders of conjunctiva in diseases classified elsewhere)',
#  429: 'H15 (disorders of sclera)',
#  430: 'H16 (keratitis)',
#  431: 'H17 (corneal scars and opacities)',
#  432: 'H18 (other disorders of cornea)',
#  433: 'H19 (disorders of sclera and cornea in diseases classified elsewhere)',
#  434: 'H20 (iridocyclitis)',
#  435: 'H21 (other disorders of iris and ciliary body)',
#  436: 'H22 (disorders of iris and ciliary body in diseases classified elsewhere)',
#  437: 'H25 (senile cataract)',
#  438: 'H26 (other cataract)',
#  439: 'H27 (other disorders of lens)',
#  440: 'H28 (cataract and other disorders of lens in diseases classified elsewhere)',
#  441: 'H30 (chorioretinal inflammation)',
#  442: 'H31 (other disorders of choroid)',
#  443: 'H32 (chorioretinal disorders in diseases classified elsewhere)',
#  444: 'H33 (retinal detachments and breaks)',
#  445: 'H34 (retinal vascular occlusions)',
#  446: 'H35 (other retinal disorders)',
#  447: 'H36 (retinal disorders in diseases classified elsewhere)',
#  448: 'H40 (glaucoma)',
#  449: 'H42 (glaucoma in diseases classified elsewhere)',
#  450: 'H43 (disorders of vitreous body)',
#  451: 'H44 (disorders of globe)',
#  452: 'H45 (disorders of vitreous body and globe in diseases classified elsewhere)',
#  453: 'H46 (optic neuritis)',
#  454: 'H47 (other disorders of optic [2nd] nerve and visual pathways)',
#  455: 'H48 (disorders of optic [2nd] nerve and visual pathways in diseases classified elsewhere)',
#  456: 'H49 (paralytic strabismus)',
#  457: 'H50 (other strabismus)',
#  458: 'H51 (other disorders of binocular movement)',
#  459: 'H52 (disorders of refraction and accommodation)',
#  460: 'H53 (visual disturbances)',
#  461: 'H54 (blindness and low vision)',
#  462: 'H55 (nystagmus and other irregular eye movements)',
#  463: 'H57 (other disorders of eye and adnexa)',
#  464: 'H58 (other disorders of eye and adnexa in diseases classified elsewhere)',
#  465: 'H59 (postprocedural disorders of eye and adnexa, not elsewhere classified)',
#  466: 'H60 (otitis externa)',
#  467: 'H61 (other disorders of external ear)',
#  468: 'H62 (disorders of external ear in diseases classified elsewhere)',
#  469: 'H65 (nonsuppurative otitis media)',
#  470: 'H66 (suppurative and unspecified otitis media)',
#  471: 'H67 (otitis media in diseases classified elsewhere)',
#  472: 'H68 (eustachian salpingitis and obstruction)',
#  473: 'H69 (other disorders of eustachian tube)',
#  474: 'H70 (mastoiditis and related conditions)',
#  475: 'H71 (cholesteatoma of middle ear)',
#  476: 'H72 (perforation of tympanic membrane)',
#  477: 'H73 (other disorders of tympanic membrane)',
#  478: 'H74 (other disorders of middle ear and mastoid)',
#  479: 'H75 (other disorders of middle ear and mastoid in diseases classified elsewhere)',
#  480: 'H80 (otosclerosis)',
#  481: 'H81 (disorders of vestibular function)',
#  482: 'H82 (vertiginous syndromes in diseases classified elsewhere)',
#  483: 'H83 (other diseases of inner ear)',
#  484: 'H90 (conductive and sensorineural hearing loss)',
#  485: 'H91 (other hearing loss)',
#  486: 'H92 (otalgia and effusion of ear)',
#  487: 'H93 (other disorders of ear, not elsewhere classified)',
#  488: 'H94 (other disorders of ear in diseases classified elsewhere)',
#  489: 'H95 (postprocedural disorders of ear and mastoid process, not elsewhere classified)',
#  490: 'I00 (rheumatic fever without mention of heart involvement)',
#  491: 'I01 (rheumatic fever with heart involvement)',
#  492: 'I02 (rheumatic chorea)',
#  493: 'I05 (rheumatic mitral valve diseases)',
#  494: 'I06 (rheumatic aortic valve diseases)',
#  495: 'I07 (rheumatic tricuspid valve diseases)',
#  496: 'I08 (multiple valve diseases)',
#  497: 'I09 (other rheumatic heart diseases)',
#  498: 'I10 (essential (primary) hypertension)',
#  499: 'I11 (hypertensive heart disease)',
#  500: 'I12 (hypertensive renal disease)',
#  501: 'I13 (hypertensive heart and renal disease)',
#  502: 'I15 (secondary hypertension)',
#  503: 'I20 (angina pectoris)',
#  504: 'I21 (acute myocardial infarction)',
#  505: 'I22 (subsequent myocardial infarction)',
#  506: 'I23 (certain current complications following acute myocardial infarction)',
#  507: 'I24 (other acute ischaemic heart diseases)',
#  508: 'I25 (chronic ischaemic heart disease)',
#  509: 'I26 (pulmonary embolism)',
#  510: 'I27 (other pulmonary heart diseases)',
#  511: 'I28 (other diseases of pulmonary vessels)',
#  512: 'I30 (acute pericarditis)',
#  513: 'I31 (other diseases of pericardium)',
#  514: 'I32 (pericarditis in diseases classified elsewhere)',
#  515: 'I33 (acute and subacute endocarditis)',
#  516: 'I34 (nonrheumatic mitral valve disorders)',
#  517: 'I35 (nonrheumatic aortic valve disorders)',
#  518: 'I36 (nonrheumatic tricuspid valve disorders)',
#  519: 'I37 (pulmonary valve disorders)',
#  520: 'I38 (endocarditis, valve unspecified)',
#  521: 'I39 (endocarditis and heart valve disorders in diseases classified elsewhere)',
#  522: 'I40 (acute myocarditis)',
#  523: 'I41 (myocarditis in diseases classified elsewhere)',
#  524: 'I42 (cardiomyopathy)',
#  525: 'I43 (cardiomyopathy in diseases classified elsewhere)',
#  526: 'I44 (atrioventricular and left bundle-branch block)',
#  527: 'I45 (other conduction disorders)',
#  528: 'I46 (cardiac arrest)',
#  529: 'I47 (paroxysmal tachycardia)',
#  530: 'I48 (atrial fibrillation and flutter)',
#  531: 'I49 (other cardiac arrhythmias)',
#  532: 'I50 (heart failure)',
#  533: 'I51 (complications and ill-defined descriptions of heart disease)',
#  534: 'I52 (other heart disorders in diseases classified elsewhere)',
#  535: 'I60 (subarachnoid haemorrhage)',
#  536: 'I61 (intracerebral haemorrhage)',
#  537: 'I62 (other nontraumatic intracranial haemorrhage)',
#  538: 'I63 (cerebral infarction)',
#  539: 'I64 (stroke, not specified as haemorrhage or infarction)',
#  540: 'I65 (occlusion and stenosis of precerebral arteries, not resulting in cerebral infarction)',
#  541: 'I66 (occlusion and stenosis of cerebral arteries, not resulting in cerebral infarction)',
#  542: 'I67 (other cerebrovascular diseases)',
#  543: 'I68 (cerebrovascular disorders in diseases classified elsewhere)',
#  544: 'I69 (sequelae of cerebrovascular disease)',
#  545: 'I70 (atherosclerosis)',
#  546: 'I71 (aortic aneurysm and dissection)',
#  547: 'I72 (other aneurysm)',
#  548: 'I73 (other peripheral vascular diseases)',
#  549: 'I74 (arterial embolism and thrombosis)',
#  550: 'I77 (other disorders of arteries and arterioles)',
#  551: 'I78 (diseases of capillaries)',
#  552: 'I79 (disorders of arteries, arterioles and capillaries in diseases classified elsewhere)',
#  553: 'I80 (phlebitis and thrombophlebitis)',
#  554: 'I81 (portal vein thrombosis)',
#  555: 'I82 (other venous embolism and thrombosis)',
#  556: 'I83 (varicose veins of lower extremities)',
#  557: 'I84 (haemorrhoids)',
#  558: 'I85 (oesophageal varices)',
#  559: 'I86 (varicose veins of other sites)',
#  560: 'I87 (other disorders of veins)',
#  561: 'I88 (nonspecific lymphadenitis)',
#  562: 'I89 (other non-infective disorders of lymphatic vessels and lymph nodes)',
#  563: 'I95 (hypotension)',
#  564: 'I97 (postprocedural disorders of circulatory system, not elsewhere classified)',
#  565: 'I98 (other disorders of circulatory system in diseases classified elsewhere)',
#  566: 'I99 (other and unspecified disorders of circulatory system)',
#  567: 'J00 (acute nasopharyngitis [common cold])',
#  568: 'J01 (acute sinusitis)',
#  569: 'J02 (acute pharyngitis)',
#  570: 'J03 (acute tonsillitis)',
#  571: 'J04 (acute laryngitis and tracheitis)',
#  572: 'J05 (acute obstructive laryngitis [croup] and epiglottitis)',
#  573: 'J06 (acute upper respiratory infections of multiple and unspecified sites)',
#  574: 'J09 (influenza due to certain identified influenza virus)',
#  575: 'J10 (influenza due to identified influenza virus)',
#  576: 'J11 (influenza, virus not identified)',
#  577: 'J12 (viral pneumonia, not elsewhere classified)',
#  578: 'J13 (pneumonia due to streptococcus pneumoniae)',
#  579: 'J14 (pneumonia due to haemophilus influenzae)',
#  580: 'J15 (bacterial pneumonia, not elsewhere classified)',
#  581: 'J16 (pneumonia due to other infectious organisms, not elsewhere classified)',
#  582: 'J17 (pneumonia in diseases classified elsewhere)',
#  583: 'J18 (pneumonia, organism unspecified)',
#  584: 'J20 (acute bronchitis)',
#  585: 'J21 (acute bronchiolitis)',
#  586: 'J22 (unspecified acute lower respiratory infection)',
#  587: 'J30 (vasomotor and allergic rhinitis)',
#  588: 'J31 (chronic rhinitis, nasopharyngitis and pharyngitis)',
#  589: 'J32 (chronic sinusitis)',
#  590: 'J33 (nasal polyp)',
#  591: 'J34 (other disorders of nose and nasal sinuses)',
#  592: 'J35 (chronic diseases of tonsils and adenoids)',
#  593: 'J36 (peritonsillar abscess)',
#  594: 'J37 (chronic laryngitis and laryngotracheitis)',
#  595: 'J38 (diseases of vocal cords and larynx, not elsewhere classified)',
#  596: 'J39 (other diseases of upper respiratory tract)',
#  597: 'J40 (bronchitis, not specified as acute or chronic)',
#  598: 'J41 (simple and mucopurulent chronic bronchitis)',
#  599: 'J42 (unspecified chronic bronchitis)',
#  600: 'J43 (emphysema)',
#  601: 'J44 (other chronic obstructive pulmonary disease)',
#  602: 'J45 (asthma)',
#  603: 'J46 (status asthmaticus)',
#  604: 'J47 (bronchiectasis)',
#  605: "J60 (coalworker's pneumoconiosis)",
#  606: 'J61 (pneumoconiosis due to asbestos and other mineral fibres)',
#  607: 'J62 (pneumoconiosis due to dust containing silica)',
#  608: 'J63 (pneumoconiosis due to other inorganic dusts)',
#  609: 'J64 (unspecified pneumoconiosis)',
#  610: 'J66 (airway disease due to specific organic dust)',
#  611: 'J67 (hypersensitivity pneumonitis due to organic dust)',
#  612: 'J68 (respiratory conditions due to inhalation of chemicals, gases, fumes and vapours)',
#  613: 'J69 (pneumonitis due to solids and liquids)',
#  614: 'J70 (respiratory conditions due to other external agents)',
#  615: 'J80 (adult respiratory distress syndrome)',
#  616: 'J81 (pulmonary oedema)',
#  617: 'J82 (pulmonary eosinophilia, not elsewhere classified)',
#  618: 'J84 (other interstitial pulmonary diseases)',
#  619: 'J85 (abscess of lung and mediastinum)',
#  620: 'J86 (pyothorax)',
#  621: 'J90 (pleural effusion, not elsewhere classified)',
#  622: 'J91 (pleural effusion in conditions classified elsewhere)',
#  623: 'J92 (pleural plaque)',
#  624: 'J93 (pneumothorax)',
#  625: 'J94 (other pleural conditions)',
#  626: 'J95 (postprocedural respiratory disorders, not elsewhere classified)',
#  627: 'J96 (respiratory failure, not elsewhere classified)',
#  628: 'J98 (other respiratory disorders)',
#  629: 'J99 (respiratory disorders in diseases classified elsewhere)',
#  630: 'K00 (disorders of tooth development and eruption)',
#  631: 'K01 (embedded and impacted teeth)',
#  632: 'K02 (dental caries)',
#  633: 'K03 (other diseases of hard tissues of teeth)',
#  634: 'K04 (diseases of pulp and periapical tissues)',
#  635: 'K05 (gingivitis and periodontal diseases)',
#  636: 'K06 (other disorders of gingiva and edentulous alveolar ridge)',
#  637: 'K07 (dentofacial anomalies [including malocclusion])',
#  638: 'K08 (other disorders of teeth and supporting structures)',
#  639: 'K09 (cysts of oral region, not elsewhere classified)',
#  640: 'K10 (other diseases of jaws)',
#  641: 'K11 (diseases of salivary glands)',
#  642: 'K12 (stomatitis and related lesions)',
#  643: 'K13 (other diseases of lip and oral mucosa)',
#  644: 'K14 (diseases of tongue)',
#  645: 'K20 (oesophagitis)',
#  646: 'K21 (gastro-oesophageal reflux disease)',
#  647: 'K22 (other diseases of oesophagus)',
#  648: 'K23 (disorders of oesophagus in diseases classified elsewhere)',
#  649: 'K25 (gastric ulcer)',
#  650: 'K26 (duodenal ulcer)',
#  651: 'K27 (peptic ulcer, site unspecified)',
#  652: 'K28 (gastrojejunal ulcer)',
#  653: 'K29 (gastritis and duodenitis)',
#  654: 'K30 (dyspepsia)',
#  655: 'K31 (other diseases of stomach and duodenum)',
#  656: 'K35 (acute appendicitis)',
#  657: 'K36 (other appendicitis)',
#  658: 'K37 (unspecified appendicitis)',
#  659: 'K38 (other diseases of appendix)',
#  660: 'K40 (inguinal hernia)',
#  661: 'K41 (femoral hernia)',
#  662: 'K42 (umbilical hernia)',
#  663: 'K43 (ventral hernia)',
#  664: 'K44 (diaphragmatic hernia)',
#  665: 'K45 (other abdominal hernia)',
#  666: 'K46 (unspecified abdominal hernia)',
#  667: "K50 (crohn's disease [regional enteritis])",
#  668: 'K51 (ulcerative colitis)',
#  669: 'K52 (other non-infective gastro-enteritis and colitis)',
#  670: 'K55 (vascular disorders of intestine)',
#  671: 'K56 (paralytic ileus and intestinal obstruction without hernia)',
#  672: 'K57 (diverticular disease of intestine)',
#  673: 'K58 (irritable bowel syndrome)',
#  674: 'K59 (other functional intestinal disorders)',
#  675: 'K60 (fissure and fistula of anal and rectal regions)',
#  676: 'K61 (abscess of anal and rectal regions)',
#  677: 'K62 (other diseases of anus and rectum)',
#  678: 'K63 (other diseases of intestine)',
#  679: 'K64 (haemorrhoids and perianal venous thrombosis)',
#  680: 'K65 (peritonitis)',
#  681: 'K66 (other disorders of peritoneum)',
#  682: 'K67 (disorders of peritoneum in infectious diseases classified elsewhere)',
#  683: 'K70 (alcoholic liver disease)',
#  684: 'K71 (toxic liver disease)',
#  685: 'K72 (hepatic failure, not elsewhere classified)',
#  686: 'K73 (chronic hepatitis, not elsewhere classified)',
#  687: 'K74 (fibrosis and cirrhosis of liver)',
#  688: 'K75 (other inflammatory liver diseases)',
#  689: 'K76 (other diseases of liver)',
#  690: 'K77 (liver disorders in diseases classified elsewhere)',
#  691: 'K80 (cholelithiasis)',
#  692: 'K81 (cholecystitis)',
#  693: 'K82 (other diseases of gallbladder)',
#  694: 'K83 (other diseases of biliary tract)',
#  695: 'K85 (acute pancreatitis)',
#  696: 'K86 (other diseases of pancreas)',
#  697: 'K87 (disorders of gallbladder, biliary tract and pancreas in diseases classified elsewhere)',
#  698: 'K90 (intestinal malabsorption)',
#  699: 'K91 (postprocedural disorders of digestive system, not elsewhere classified)',
#  700: 'K92 (other diseases of digestive system)',
#  701: 'K93 (disorders of other digestive organs in diseases classified elsewhere)',
#  702: 'L00 (staphylococcal scalded skin syndrome)',
#  703: 'L01 (impetigo)',
#  704: 'L02 (cutaneous abscess, furuncle and carbuncle)',
#  705: 'L03 (cellulitis)',
#  706: 'L04 (acute lymphadenitis)',
#  707: 'L05 (pilonidal cyst)',
#  708: 'L08 (other local infections of skin and subcutaneous tissue)',
#  709: 'L10 (pemphigus)',
#  710: 'L11 (other acantholytic disorders)',
#  711: 'L12 (pemphigoid)',
#  712: 'L13 (other bullous disorders)',
#  713: 'L14 (bullous disorders in diseases classified elsewhere)',
#  714: 'L20 (atopic dermatitis)',
#  715: 'L21 (seborrhoeic dermatitis)',
#  716: 'L22 (diaper [napkin] dermatitis)',
#  717: 'L23 (allergic contact dermatitis)',
#  718: 'L24 (irritant contact dermatitis)',
#  719: 'L25 (unspecified contact dermatitis)',
#  720: 'L26 (exfoliative dermatitis)',
#  721: 'L27 (dermatitis due to substances taken internally)',
#  722: 'L28 (lichen simplex chronicus and prurigo)',
#  723: 'L29 (pruritus)',
#  724: 'L30 (other dermatitis)',
#  725: 'L40 (psoriasis)',
#  726: 'L41 (parapsoriasis)',
#  727: 'L42 (pityriasis rosea)',
#  728: 'L43 (lichen planus)',
#  729: 'L44 (other papulosquamous disorders)',
#  730: 'L50 (urticaria)',
#  731: 'L51 (erythema multiforme)',
#  732: 'L52 (erythema nodosum)',
#  733: 'L53 (other erythematous conditions)',
#  734: 'L54 (erythema in diseases classified elsewhere)',
#  735: 'L55 (sunburn)',
#  736: 'L56 (other acute skin changes due to ultraviolet radiation)',
#  737: 'L57 (skin changes due to chronic exposure to nonionising radiation)',
#  738: 'L58 (radiodermatitis)',
#  739: 'L59 (other disorders of skin and subcutaneous tissue related to radiation)',
#  740: 'L60 (nail disorders)',
#  741: 'L62 (nail disorders in diseases classified elsewhere)',
#  742: 'L63 (alopecia areata)',
#  743: 'L64 (androgenic alopecia)',
#  744: 'L65 (other nonscarring hair loss)',
#  745: 'L66 (cicatricial alopecia [scarring hair loss])',
#  746: 'L67 (hair colour and hair shaft abnormalities)',
#  747: 'L68 (hypertrichosis)',
#  748: 'L70 (acne)',
#  749: 'L71 (rosacea)',
#  750: 'L72 (follicular cysts of skin and subcutaneous tissue)',
#  751: 'L73 (other follicular disorders)',
#  752: 'L74 (eccrine sweat disorders)',
#  753: 'L75 (apocrine sweat disorders)',
#  754: 'L80 (vitiligo)',
#  755: 'L81 (other disorders of pigmentation)',
#  756: 'L82 (seborrhoeic keratosis)',
#  757: 'L83 (acanthosis nigricans)',
#  758: 'L84 (corns and callosities)',
#  759: 'L85 (other epidermal thickening)',
#  760: 'L86 (keratoderma in diseases classified elsewhere)',
#  761: 'L87 (transepidermal elimination disorders)',
#  762: 'L88 (pyoderma gangrenosum)',
#  763: 'L89 (decubitus ulcer)',
#  764: 'L90 (atrophic disorders of skin)',
#  765: 'L91 (hypertrophic disorders of skin)',
#  766: 'L92 (granulomatous disorders of skin and subcutaneous tissue)',
#  767: 'L93 (lupus erythematosus)',
#  768: 'L94 (other localised connective tissue disorders)',
#  769: 'L95 (vasculitis limited to skin, not elsewhere classified)',
#  770: 'L97 (ulcer of lower limb, not elsewhere classified)',
#  771: 'L98 (other disorders of skin and subcutaneous tissue, not elsewhere classified)',
#  772: 'L99 (other disorders of skin and subcutaneous tissue in diseases classified elsewhere)',
#  773: 'M00 (pyogenic arthritis)',
#  774: 'M01 (direct infections of joint in infectious and parasitic diseases classified elsewhere)',
#  775: 'M02 (reactive arthropathies)',
#  776: 'M03 (postinfective and reactive arthropathies in diseases classified elsewhere)',
#  777: 'M05 (seropositive rheumatoid arthritis)',
#  778: 'M06 (other rheumatoid arthritis)',
#  779: 'M07 (psoriatic and enteropathic arthropathies)',
#  780: 'M08 (juvenile arthritis)',
#  781: 'M09 (juvenile arthritis in diseases classified elsewhere)',
#  782: 'M10 (gout)',
#  783: 'M11 (other crystal arthropathies)',
#  784: 'M12 (other specific arthropathies)',
#  785: 'M13 (other arthritis)',
#  786: 'M14 (arthropathies in other diseases classified elsewhere)',
#  787: 'M15 (polyarthrosis)',
#  788: 'M16 (coxarthrosis [arthrosis of hip])',
#  789: 'M17 (gonarthrosis [arthrosis of knee])',
#  790: 'M18 (arthrosis of first carpometacarpal joint)',
#  791: 'M19 (other arthrosis)',
#  792: 'M20 (acquired deformities of fingers and toes)',
#  793: 'M21 (other acquired deformities of limbs)',
#  794: 'M22 (disorders of patella)',
#  795: 'M23 (internal derangement of knee)',
#  796: 'M24 (other specific joint derangements)',
#  797: 'M25 (other joint disorders, not elsewhere classified)',
#  798: 'M30 (polyarteritis nodosa and related conditions)',
#  799: 'M31 (other necrotising vasculopathies)',
#  800: 'M32 (systemic lupus erythematosus)',
#  801: 'M33 (dermatopolymyositis)',
#  802: 'M34 (systemic sclerosis)',
#  803: 'M35 (other systemic involvement of connective tissue)',
#  804: 'M36 (systemic disorders of connective tissue in diseases classified elsewhere)',
#  805: 'M40 (kyphosis and lordosis)',
#  806: 'M41 (scoliosis)',
#  807: 'M42 (spinal osteochondrosis)',
#  808: 'M43 (other deforming dorsopathies)',
#  809: 'M45 (ankylosing spondylitis)',
#  810: 'M46 (other inflammatory spondylopathies)',
#  811: 'M47 (spondylosis)',
#  812: 'M48 (other spondylopathies)',
#  813: 'M49 (spondylopathies in diseases classified elsewhere)',
#  814: 'M50 (cervical disk disorders)',
#  815: 'M51 (other intervertebral disk disorders)',
#  816: 'M53 (other dorsopathies, not elsewhere classified)',
#  817: 'M54 (dorsalgia)',
#  818: 'M60 (myositis)',
#  819: 'M61 (calcification and ossification of muscle)',
#  820: 'M62 (other disorders of muscle)',
#  821: 'M63 (disorders of muscle in diseases classified elsewhere)',
#  822: 'M65 (synovitis and tenosynovitis)',
#  823: 'M66 (spontaneous rupture of synovium and tendon)',
#  824: 'M67 (other disorders of synovium and tendon)',
#  825: 'M68 (disorders of synovium and tendon in diseases classified elsewhere)',
#  826: 'M70 (soft tissue disorders related to use, overuse and pressure)',
#  827: 'M71 (other bursopathies)',
#  828: 'M72 (fibroblastic disorders)',
#  829: 'M73 (soft tissue disorders in diseases classified elsewhere)',
#  830: 'M75 (shoulder lesions)',
#  831: 'M76 (enthesopathies of lower limb, excluding foot)',
#  832: 'M77 (other enthesopathies)',
#  833: 'M79 (other soft tissue disorders, not elsewhere classified)',
#  834: 'M80 (osteoporosis with pathological fracture)',
#  835: 'M81 (osteoporosis without pathological fracture)',
#  836: 'M82 (osteoporosis in diseases classified elsewhere)',
#  837: 'M83 (adult osteomalacia)',
#  838: 'M84 (disorders of continuity of bone)',
#  839: 'M85 (other disorders of bone density and structure)',
#  840: 'M86 (osteomyelitis)',
#  841: 'M87 (osteonecrosis)',
#  842: "M88 (paget's disease of bone [osteitis deformans])",
#  843: 'M89 (other disorders of bone)',
#  844: 'M90 (osteopathies in diseases classified elsewhere)',
#  845: 'M91 (juvenile osteochondrosis of hip and pelvis)',
#  846: 'M92 (other juvenile osteochondrosis)',
#  847: 'M93 (other osteochondropathies)',
#  848: 'M94 (other disorders of cartilage)',
#  849: 'M95 (other acquired deformities of musculoskeletal system and connective tissue)',
#  850: 'M96 (postprocedural musculoskeletal disorders, not elsewhere classified)',
#  851: 'M99 (biomechanical lesions, not elsewhere classified)',
#  852: 'N00 (acute nephritic syndrome)',
#  853: 'N01 (rapidly progressive nephritic syndrome)',
#  854: 'N02 (recurrent and persistent haematuria)',
#  855: 'N03 (chronic nephritic syndrome)',
#  856: 'N04 (nephrotic syndrome)',
#  857: 'N05 (unspecified nephritic syndrome)',
#  858: 'N06 (isolated proteinuria with specified morphological lesion)',
#  859: 'N07 (hereditary nephropathy, not elsewhere classified)',
#  860: 'N08 (glomerular disorders in diseases classified elsewhere)',
#  861: 'N10 (acute tubulo-interstitial nephritis)',
#  862: 'N11 (chronic tubulo-interstitial nephritis)',
#  863: 'N12 (tubulo-interstitial nephritis, not specified as acute or chronic)',
#  864: 'N13 (obstructive and reflux uropathy)',
#  865: 'N14 (drug- and heavy-metal-induced tubulo-interstitial and tubular conditions)',
#  866: 'N15 (other renal tubulo-interstitial diseases)',
#  867: 'N16 (renal tubulo-interstitial disorders in diseases classified elsewhere)',
#  868: 'N17 (acute renal failure)',
#  869: 'N18 (chronic renal failure)',
#  870: 'N19 (unspecified renal failure)',
#  871: 'N20 (calculus of kidney and ureter)',
#  872: 'N21 (calculus of lower urinary tract)',
#  873: 'N22 (calculus of urinary tract in diseases classified elsewhere)',
#  874: 'N23 (unspecified renal colic)',
#  875: 'N25 (disorders resulting from impaired renal tubular function)',
#  876: 'N26 (unspecified contracted kidney)',
#  877: 'N27 (small kidney of unknown cause)',
#  878: 'N28 (other disorders of kidney and ureter, not elsewhere classified)',
#  879: 'N29 (other disorders of kidney and ureter in diseases classified elsewhere)',
#  880: 'N30 (cystitis)',
#  881: 'N31 (neuromuscular dysfunction of bladder, not elsewhere classified)',
#  882: 'N32 (other disorders of bladder)',
#  883: 'N33 (bladder disorders in diseases classified elsewhere)',
#  884: 'N34 (urethritis and urethral syndrome)',
#  885: 'N35 (urethral stricture)',
#  886: 'N36 (other disorders of urethra)',
#  887: 'N37 (urethral disorders in diseases classified elsewhere)',
#  888: 'N39 (other disorders of urinary system)',
#  889: 'N40 (hyperplasia of prostate)',
#  890: 'N41 (inflammatory diseases of prostate)',
#  891: 'N42 (other disorders of prostate)',
#  892: 'N43 (hydrocele and spermatocele)',
#  893: 'N44 (torsion of testis)',
#  894: 'N45 (orchitis and epididymitis)',
#  895: 'N46 (male infertility)',
#  896: 'N47 (redundant prepuce, phimosis and paraphimosis)',
#  897: 'N48 (other disorders of penis)',
#  898: 'N49 (inflammatory disorders of male genital organs, not elsewhere classified)',
#  899: 'N50 (other disorders of male genital organs)',
#  900: 'N51 (disorders of male genital organs in diseases classified elsewhere)',
#  901: 'N60 (benign mammary dysplasia)',
#  902: 'N61 (inflammatory disorders of breast)',
#  903: 'N62 (hypertrophy of breast)',
#  904: 'N63 (unspecified lump in breast)',
#  905: 'N64 (other disorders of breast)',
#  906: 'N70 (salpingitis and oophoritis)',
#  907: 'N71 (inflammatory disease of uterus, except cervix)',
#  908: 'N72 (inflammatory disease of cervix uteri)',
#  909: 'N73 (other female pelvic inflammatory diseases)',
#  910: 'N74 (female pelvic inflammatory disorders in diseases classified elsewhere)',
#  911: "N75 (diseases of bartholin's gland)",
#  912: 'N76 (other inflammation of vagina and vulva)',
#  913: 'N77 (vulvovaginal ulceration and inflammation in diseases classified elsewhere)',
#  914: 'N80 (endometriosis)',
#  915: 'N81 (female genital prolapse)',
#  916: 'N82 (fistulae involving female genital tract)',
#  917: 'N83 (noninflammatory disorders of ovary, fallopian tube and broad ligament)',
#  918: 'N84 (polyp of female genital tract)',
#  919: 'N85 (other noninflammatory disorders of uterus, except cervix)',
#  920: 'N86 (erosion and ectropion of cervix uteri)',
#  921: 'N87 (dysplasia of cervix uteri)',
#  922: 'N88 (other noninflammatory disorders of cervix uteri)',
#  923: 'N89 (other noninflammatory disorders of vagina)',
#  924: 'N90 (other noninflammatory disorders of vulva and perineum)',
#  925: 'N91 (absent, scanty and rare menstruation)',
#  926: 'N92 (excessive, frequent and irregular menstruation)',
#  927: 'N93 (other abnormal uterine and vaginal bleeding)',
#  928: 'N94 (pain and other conditions associated with female genital organs and menstrual cycle)',
#  929: 'N95 (menopausal and other perimenopausal disorders)',
#  930: 'N96 (habitual aborter)',
#  931: 'N97 (female infertility)',
#  932: 'N98 (complications associated with artificial fertilisation)',
#  933: 'N99 (postprocedural disorders of genito-urinary system, not elsewhere classified)',
#  934: 'O00 (ectopic pregnancy)',
#  935: 'O01 (hydatidiform mole)',
#  936: 'O02 (other abnormal products of conception)',
#  937: 'O03 (spontaneous abortion)',
#  938: 'O04 (medical abortion)',
#  939: 'O05 (other abortion)',
#  940: 'O06 (unspecified abortion)',
#  941: 'O07 (failed attempted abortion)',
#  942: 'O08 (complications following abortion and ectopic and molar pregnancy)',
#  943: 'O10 (pre-existing hypertension complicating pregnancy, childbirth and the puerperium)',
#  944: 'O11 (pre-existing hypertensive disorder with superimposed proteinuria)',
#  945: 'O12 (gestational [pregnancy-induced] oedema and proteinuria without hypertension)',
#  946: 'O13 (gestational [pregnancy-induced] hypertension without significant proteinuria)',
#  947: 'O14 (gestational [pregnancy-induced] hypertension with significant proteinuria)',
#  948: 'O15 (eclampsia)',
#  949: 'O16 (unspecified maternal hypertension)',
#  950: 'O20 (haemorrhage in early pregnancy)',
#  951: 'O21 (excessive vomiting in pregnancy)',
#  952: 'O22 (venous complications in pregnancy)',
#  953: 'O23 (infections of genito-urinary tract in pregnancy)',
#  954: 'O24 (diabetes mellitus in pregnancy)',
#  955: 'O25 (malnutrition in pregnancy)',
#  956: 'O26 (maternal care for other conditions predominantly related to pregnancy)',
#  957: 'O28 (abnormal findings on antenatal screening of mother)',
#  958: 'O29 (complications of anaesthesia during pregnancy)',
#  959: 'O30 (multiple gestation)',
#  960: 'O31 (complications specific to multiple gestation)',
#  961: 'O32 (maternal care for known or suspected malpresentation of foetus)',
#  962: 'O33 (maternal care for known or suspected disproportion)',
#  963: 'O34 (maternal care for known or suspected abnormality of pelvic organs)',
#  964: 'O35 (maternal care for known or suspected foetal abnormality and damage)',
#  965: 'O36 (maternal care for other known or suspected foetal problems)',
#  966: 'O40 (polyhydramnios)',
#  967: 'O41 (other disorders of amniotic fluid and membranes)',
#  968: 'O42 (premature rupture of membranes)',
#  969: 'O43 (placental disorders)',
#  970: 'O44 (placenta praevia)',
#  971: 'O45 (premature separation of placenta [abruptio placentae])',
#  972: 'O46 (antepartum haemorrhage, not elsewhere classified)',
#  973: 'O47 (false labour)',
#  974: 'O48 (prolonged pregnancy)',
#  975: 'O60 (preterm delivery)',
#  976: 'O61 (failed induction of labour)',
#  977: 'O62 (abnormalities of forces of labour)',
#  978: 'O63 (long labour)',
#  979: 'O64 (obstructed labour due to malposition and malpresentation of foetus)',
#  980: 'O65 (obstructed labour due to maternal pelvic abnormality)',
#  981: 'O66 (other obstructed labour)',
#  982: 'O67 (labour and delivery complicated by intrapartum haemorrhage, not elsewhere classified)',
#  983: 'O68 (labour and delivery complicated by foetal stress [distress])',
#  984: 'O69 (labour and delivery complicated by umbilical cord complications)',
#  985: 'O70 (perineal laceration during delivery)',
#  986: 'O71 (other obstetric trauma)',
#  987: 'O72 (postpartum haemorrhage)',
#  988: 'O73 (retained placenta and membranes, without haemorrhage)',
#  989: 'O74 (complications of anaesthesia during labour and delivery)',
#  990: 'O75 (other complications of labour and delivery, not elsewhere classified)',
#  991: 'O80 (single spontaneous delivery)',
#  992: 'O81 (single delivery by forceps and vacuum extractor)',
#  993: 'O82 (single delivery by caesarean section)',
#  994: 'O83 (other assisted single delivery)',
#  995: 'O84 (multiple delivery)',
#  996: 'O85 (puerperal sepsis)',
#  997: 'O86 (other puerperal infections)',
#  998: 'O87 (venous complications in the puerperium)',
#  999: 'O88 (obstetric embolism)',
#  ...}

# %%
df["label"] = df["token_id"].map(label_dict)

print("\n라벨이 추가된 데이터:")
print(df.head(20))
print(f"\n라벨이 없는 token_id 개수: {df['label'].isna().sum()}")
# Out:
# 라벨이 추가된 데이터:
#     patient_id  patient_age_days  token_id  \
# 0       402867              1251       602
# 1       402867              8870       724
# 2       402867             15534       714
# 3       402867             21457       498
# 4       402867             21834       265
# 5       402867             21871       833
# 6       402867             22127       372
# 7       402867             23264       660
# 8       402867             23451       382
# 9       402867             23811      1197
# 10      402867             24322       797
# 11      402867             24386       467
# 12      402867             24486       817
# 13      402867             24500       835
# 14      402867             25921       427
# 15      402867             26032       586
# 16      402867             26896      1181
# 17      402867             27195       822
# 18      402867             27710       508
# 19      402867             27996       542
#
#                                                 label
# 0                                        J45 (asthma)
# 1                              L30 (other dermatitis)
# 2                             L20 (atopic dermatitis)
# 3              I10 (essential (primary) hypertension)
# 4   E78 (disorders of lipoprotein metabolism and o...
# 5   M79 (other soft tissue disorders, not elsewher...
# 6   G25 (other extrapyramidal and movement disorders)
# 7                               K40 (inguinal hernia)
# 8                      G44 (other headache syndromes)
# 9                  C61 Malignant neoplasm of prostate
# 10  M25 (other joint disorders, not elsewhere clas...
# 11              H61 (other disorders of external ear)
# 12                                    M54 (dorsalgia)
# 13   M81 (osteoporosis without pathological fracture)
# 14               H11 (other disorders of conjunctiva)
# 15  J22 (unspecified acute lower respiratory infec...
# 16              C44 Other malignant neoplasms of skin
# 17                  M65 (synovitis and tenosynovitis)
# 18              I25 (chronic ischaemic heart disease)
# 19               I67 (other cerebrovascular diseases)
#
# 라벨이 없는 token_id 개수: 0

# %%
# token_id의 최소값과 최대값 확인
token_min = df["token_id"].min()
token_max = df["token_id"].max()
print(f"\ntoken_id 최소값: {token_min}")
print(f"token_id 최대값: {token_max}")
print(f"token_id 범위: {token_min} ~ {token_max}")

# token_id가 1 또는 2인 관측치의 patient_id가 서로 겹치지 않고 unique한지 확인
df_token_1 = df[df["token_id"] == 1]
df_token_2 = df[df["token_id"] == 2]

patient_ids_token_1 = set(df_token_1["patient_id"].unique())
patient_ids_token_2 = set(df_token_2["patient_id"].unique())

print(f"\n=== token_id 1과 2의 patient_id 겹침 확인 ===")
print(f"token_id 1인 관측치 개수: {len(df_token_1)}")
print(f"token_id 1인 unique patient_id 개수: {len(patient_ids_token_1)}")
print(f"token_id 2인 관측치 개수: {len(df_token_2)}")
print(f"token_id 2인 unique patient_id 개수: {len(patient_ids_token_2)}")

# 교집합 확인
intersection = patient_ids_token_1 & patient_ids_token_2
print(f"\n겹치는 patient_id 개수: {len(intersection)}")
if len(intersection) > 0:
    print(f"⚠️ 경고: token_id 1과 2에 공통으로 나타나는 patient_id가 {len(intersection)}개 있습니다!")
    print(f"겹치는 patient_id (처음 10개): {sorted(list(intersection))[:10]}")
else:
    print("✓ token_id 1과 2의 patient_id는 완전히 겹치지 않습니다 (unique합니다).")
# Out:
# token_id 최소값: 1
# token_id 최대값: 1268
# token_id 범위: 1 ~ 1268
#
# === token_id 1과 2의 patient_id 겹침 확인 ===
# token_id 1인 관측치 개수: 3639
# token_id 1인 unique patient_id 개수: 3639
# token_id 2인 관측치 개수: 3503
# token_id 2인 unique patient_id 개수: 3503
#
# 겹치는 patient_id 개수: 0
# ✓ token_id 1과 2의 patient_id는 완전히 겹치지 않습니다 (unique합니다).

# %%
# 특정 patient_id로 필터링 (예시)
df_filtered = df[df["patient_id"] == 402868]
df_filtered = df_filtered.copy()
df_filtered["patient_age_years"] = df_filtered["patient_age_days"] / 365.25
print("\n필터링된 데이터 (patient_id == 402868):")
print(df_filtered)
# Out:
# 필터링된 데이터 (patient_id == 402868):
#     patient_id  patient_age_days  token_id  \
# 26      402868                 0         1
# 27      402868             11184       991
# 28      402868             13919       817
# 29      402868             14272       306
# 30      402868             14835       815
# 31      402868             16275       832
# 32      402868             17010       918
# 33      402868             17849       679
# 34      402868             17863       576
# 35      402868             17927       797
# 36      402868             17936       587
# 37      402868             18450       466
# 38      402868             18536       472
# 39      402868             18730       470
# 40      402868             18975       486
# 41      402868             19851       450
# 42      402868             19881       737
# 43      402868             20294       484
# 44      402868             20451        99
# 45      402868             21044       771
# 46      402868             22294        16
# 47      402868             22434       591
# 48      402868             23135       590
# 49      402868             23563       791
# 50      402868             23710       826
# 51      402868             24060       265
# 52      402868             24378       527
# 53      402868             24905        95
# 54      402868             25603       454
# 55      402868             26540       254
# 56      402868             26637       647
# 57      402868             26792       602
# 58      402868             27849       310
# 59      402868             28227       304
# 60      402868             28334       533
# 61      402868             28923       793
#
#                                                 label  patient_age_years
# 26                                             Female           0.000000
# 27                  O80 (single spontaneous delivery)          30.620123
# 28                                    M54 (dorsalgia)          38.108145
# 29        F34 (persistent mood [affective] disorders)          39.074606
# 30          M51 (other intervertebral disk disorders)          40.616016
# 31                         M77 (other enthesopathies)          44.558522
# 32                N84 (polyp of female genital tract)          46.570842
# 33  K64 (haemorrhoids and perianal venous thrombosis)          48.867899
# 34              J11 (influenza, virus not identified)          48.906229
# 35  M25 (other joint disorders, not elsewhere clas...          49.081451
# 36              J30 (vasomotor and allergic rhinitis)          49.106092
# 37                               H60 (otitis externa)          50.513347
# 38       H68 (eustachian salpingitis and obstruction)          50.748802
# 39     H66 (suppurative and unspecified otitis media)          51.279945
# 40                  H92 (otalgia and effusion of ear)          51.950719
# 41                   H43 (disorders of vitreous body)          54.349076
# 42  L57 (skin changes due to chronic exposure to n...          54.431211
# 43    H90 (conductive and sensorineural hearing loss)          55.561944
# 44                                  B07 (viral warts)          55.991786
# 45  L98 (other disorders of skin and subcutaneous ...          57.615332
# 46        A04 (other bacterial intestinal infections)          61.037645
# 47    J34 (other disorders of nose and nasal sinuses)          61.420945
# 48                                  J33 (nasal polyp)          63.340178
# 49                              M19 (other arthrosis)          64.511978
# 50  M70 (soft tissue disorders related to use, ove...          64.914442
# 51  E78 (disorders of lipoprotein metabolism and o...          65.872690
# 52                   I45 (other conduction disorders)          66.743326
# 53                       B02 (zoster [herpes zoster])          68.186174
# 54  H47 (other disorders of optic [2nd] nerve and ...          70.097194
# 55                                      E66 (obesity)          72.662560
# 56                 K22 (other diseases of oesophagus)          72.928131
# 57                                       J45 (asthma)          73.352498
# 58                      F41 (other anxiety disorders)          76.246407
# 59                           F32 (depressive episode)          77.281314
# 60  I51 (complications and ill-defined description...          77.574264
# 61          M21 (other acquired deformities of limbs)          79.186858

# %%
(df['patient_id'].unique())
# Out:
# array([402867, 402868, 402869, ..., 427983, 427984, 427985], dtype=uint32)

# %%
df_token_dm = df[df["token_id"] == 214]
df_token_dm
# Out:
#         patient_id  patient_age_days  token_id  \
# 112         402875             27745       214
# 176         402884             28193       214
# 373         402900             27480       214
# 501         402923             28769       214
# 544         402933             16655       214
# ...            ...               ...       ...
# 180588      427908             27707       214
# 180927      427945             22981       214
# 181070      427956             26225       214
# 181110      427962             23852       214
# 181230      427983             23063       214
#
#                                                 label
# 112     E11 (non-insulin-dependent diabetes mellitus)
# 176     E11 (non-insulin-dependent diabetes mellitus)
# 373     E11 (non-insulin-dependent diabetes mellitus)
# 501     E11 (non-insulin-dependent diabetes mellitus)
# 544     E11 (non-insulin-dependent diabetes mellitus)
# ...                                               ...
# 180588  E11 (non-insulin-dependent diabetes mellitus)
# 180927  E11 (non-insulin-dependent diabetes mellitus)
# 181070  E11 (non-insulin-dependent diabetes mellitus)
# 181110  E11 (non-insulin-dependent diabetes mellitus)
# 181230  E11 (non-insulin-dependent diabetes mellitus)
#
# [1250 rows x 4 columns]

# %%
# 특정 patient_id로 필터링 (예시)
df_filtered = df[df["patient_id"] == 402875]
df_filtered = df_filtered.copy()
df_filtered["patient_age_years"] = df_filtered["patient_age_days"] / 365.25
print("\n필터링된 데이터 (patient_id == 402875):")
print(df_filtered.head())
# Out:
# 필터링된 데이터 (patient_id == 402875):
#      patient_id  patient_age_days  token_id  \
# 98       402875                 0         2
# 99       402875             22611       874
# 100      402875             23084       889
# 101      402875             23845       737
# 102      402875             24034       833
#
#                                                  label  patient_age_years
# 98                                                Male           0.000000
# 99                       N23 (unspecified renal colic)          61.905544
# 100                      N40 (hyperplasia of prostate)          63.200548
# 101  L57 (skin changes due to chronic exposure to n...          65.284052
# 102  M79 (other soft tissue disorders, not elsewher...          65.801506
